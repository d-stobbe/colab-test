# %%
# !git clone https://github.com/d-stobbe/colab-test
# Out:
# fatal: destination path 'colab-test' already exists and is not an empty directory.

# %%
# %cd /content/colab-test
# !git pull
# Out:
# /content/colab-test
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 2 (delta 0), reused 2 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (2/2), 238 bytes | 238.00 KiB/s, done.
# From https://github.com/d-stobbe/colab-test
#    fe9582d..9710f36  main       -> origin/main
# Updating fe9582d..9710f36
# Fast-forward
#  test.py => mytest.py | 0
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  rename test.py => mytest.py (100%)

# %%
import sys
sys.path.append('/content/colabp-test')
from mytest import message # type: ignore
message()
# Out:
# Hello World
